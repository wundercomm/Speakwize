# %% [markdown]
# <a href="https://colab.research.google.com/github/arpagon/podcast-coffeebreak/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Detect GPU

# %%
# !nvidia-smi
# Out:
# Thu Oct 27 11:54:21 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.141.03   Driver Version: 470.141.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:09:00.0  On |                  N/A |
# | 26%   39C    P8    13W / 100W |    454MiB /  3903MiB |     19%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      5017      G   /usr/lib/xorg/Xorg                162MiB |
# |    0   N/A  N/A      5420      G   /usr/bin/gnome-shell              123MiB |
# |    0   N/A  N/A      6313      G   ...e/Steam/ubuntu12_32/steam        6MiB |
# |    0   N/A  N/A      6608      G   ...RendererForSitePerProcess       15MiB |
# |    0   N/A  N/A      7468      G   /usr/lib/insync/insync              2MiB |
# |    0   N/A  N/A      7629      G   ...ef_log.txt --shared-files        3MiB |
# |    0   N/A  N/A   1466237      G   ...5/usr/lib/firefox/firefox      136MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Install CondaColab

# %%
# %pip install -q condacolab
import condacolab
condacolab.install()

# %% [markdown]
# # Check CondaColab it's ok

# %%
import condacolab
condacolab.check()

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# /opt/arpagon/mambaforge/envs/OpenAIWhisper/lib/python3.10/site-packages/google/colab/data_table.py:30: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   from IPython.utils import traitlets as _traitlets
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [1], line 2
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# File /opt/arpagon/mambaforge/envs/OpenAIWhisper/lib/python3.10/site-packages/google/colab/drive.py:82, in mount(mountpoint, force_remount, timeout_ms)
#      77   print('Drive already mounted at {}; to attempt to forcibly remount, '
#      78         'call drive.mount("{}", force_remount=True).'.format(
#      79             mountpoint, mountpoint))
#      80   return
# ---> 82 env = _env()
#      83 home = env.home
#      84 root_dir = env.root_dir
#
# File /opt/arpagon/mambaforge/envs/OpenAIWhisper/lib/python3.10/site-packages/google/colab/drive.py:43, in _env()
#      40 """Create and return an _Environment to use."""
#      41 home = _os.environ['HOME']
#      42 root_dir = _os.path.realpath(
# ---> 43     _os.path.join(_os.environ['CLOUDSDK_CONFIG'], '../..'))
#      44 inet_family = 'IPV4_ONLY'
#      45 dev = '/dev/fuse'
#
# File /opt/arpagon/mambaforge/envs/OpenAIWhisper/lib/python3.10/os.py:679, in _Environ.__getitem__(self, key)
#     676     value = self._data[self.encodekey(key)]
#     677 except KeyError:
#     678     # raise KeyError with the original key value
# --> 679     raise KeyError(key) from None
#     680 return self.decodevalue(value)
#
# KeyError: 'CLOUDSDK_CONFIG'

# %%
podcast_audio_directory = '/media/arpagon/archive-data/Insync/arpagon@gmail.com/AI/podcast/audio'
podcast_text_directory = '/media/arpagon/archive-data/Insync/arpagon@gmail.com/AI/podcast/text'
podcast_stats_csv = '/media/arpagon/archive-data/Insync/arpagon@gmail.com/AI/podcast/stats_local.csv'
whisper_model = 'tiny'
decode_options = {"language": "es"}

# %%
# !mkdir -p {podcast_audio_directory}
# !mkdir -p {podcast_text_directory}

# %% [markdown]
# # Clone Repo

# %%
# !git clone https://github.com/arpagon/podcast-coffeebreak.git

# %% [markdown]
# # Install my env

# %%
# !mamba env update -n base -f /content/podcast-coffeebreak/environment.yml

# %% [markdown]
# # Check youtube-dl Version

# %%
# !youtube-dl --version

# %% [markdown]
# # Download Podcast

# %%
# !bash /content/podcast-coffeebreak/utils/000_download_podcast.sh -u 'https://podcasts.google.com/feed/aHR0cDovL2ZlZWRzLmZlZWRidXJuZXIuY29tL1BvZGNhc3RDb2ZmZWVCcmVhaw?sa=X&ved=0CD4Q9sEGahcKEwjw1Zv4i8_6AhUAAAAAHQAAAAAQEw' -d /content/drive/MyDrive/AI/podcast/audio

# %%
import os
import whisper
import json
import time
import pandas as pd


df = pd.DataFrame(columns=
        [
            'id',
            'filename',
            'audio_filename',
            'text_filename',
            'size_in_bytes',
            'size_in_sconds',
            'transcribe_status',
            'transcribe_start',
            'transcribe_end',
            'transcribe_duration',
            'transcribe_model',
            'transcribe_language'
        ]
)
df = df.set_index('id')
model = whisper.load_model(whisper_model)

for filename in sorted(os.listdir(podcast_audio_directory)):
    id=filename.split('.')[0] + "_" + whisper_model
    audio_filename = os.path.join(podcast_audio_directory, filename)
    if not whisper_model == "medium":
        text_filename = os.path.join(podcast_text_directory, filename.split('.')[0] + "_" + whisper_model + '.json')
    else:
        text_filename = os.path.join(podcast_text_directory, filename.split('.')[0] + '.json')
    size_in_bytes = os.path.getsize(audio_filename)
    # size_in_sconds=audio.info.length
    df.loc[id]={
            "id": id,
            "filename": filename.split('.')[0],
            "audio_filename": audio_filename,
            "text_filename": text_filename,
            "size_in_bytes": size_in_bytes,
            # "size_in_sconds": size_in_sconds
    }
    if not os.path.exists(text_filename):
        if os.path.isfile(audio_filename):
            transcribe_start = time.time()
            print('\r transcribing {0} at {1}'.format(audio_filename, transcribe_start))
            result = model.transcribe(audio_filename, **decode_options)
            transcribe_end = time.time()
            transcribe_duration = transcribe_end - transcribe_start
            transcribe_status = "1"
            transcribe_model=model
            with open(text_filename, 'w',encoding='utf8') as text_filename_file:
                print('\r Writing {0}'.format(text_filename))
                json.dump(result, text_filename_file, indent=4)
            print('\r end transcribe {0} at {1} duration of {2} sec'.format(audio_filename, transcribe_end, transcribe_duration))
            df.loc[id]={
                "transcribe_status": transcribe_status,
                "transcribe_start": transcribe_start,
                "transcribe_end": transcribe_end,
                "transcribe_duration": transcribe_duration,
                "transcribe_model": whisper_model,
                "transcribe_language": decode_options["language"]
            }
    df.to_csv(podcast_stats_csv, mode='a', index=True, header=True)
    print("\r {0} Data appended successfully".format(id))
# Out:
#  001_tiny Data appended successfully
#  002_tiny Data appended successfully
#  003_tiny Data appended successfully
#  004_tiny Data appended successfully
#  005_tiny Data appended successfully
#  006_tiny Data appended successfully
#  007_tiny Data appended successfully
#  008_tiny Data appended successfully
#  009_tiny Data appended successfully
#  010_tiny Data appended successfully
#  011_tiny Data appended successfully
#  012_tiny Data appended successfully
#  013_tiny Data appended successfully
#  014_tiny Data appended successfully
#  015_tiny Data appended successfully
#  016_tiny Data appended successfully
#  017_tiny Data appended successfully
#  018_tiny Data appended successfully
#  019_tiny Data appended successfully
#  020_tiny Data appended successfully
#  021_tiny Data appended successfully
#  022_tiny Data appended successfully
#  023_tiny Data appended successfully
#  024_tiny Data appended successfully
#  025_tiny Data appended successfully
#  026_tiny Data appended successfully
#  027_tiny Data appended successfully
#  028_tiny Data appended successfully
#  029_tiny Data appended successfully
#  030_tiny Data appended successfully
#  031_tiny Data appended successfully
#  032_tiny Data appended successfully
#  033_tiny Data appended successfully
#  034_tiny Data appended successfully
#  035_tiny Data appended successfully
#  036_tiny Data appended successfully
#  037_tiny Data appended successfully
#  038_tiny Data appended successfully
#  039_tiny Data appended successfully
#  040_tiny Data appended successfully
#  041_tiny Data appended successfully
#  042_tiny Data appended successfully
#  043_tiny Data appended successfully
#  044_tiny Data appended successfully
#  045_tiny Data appended successfully
#  046_tiny Data appended successfully
#  047_tiny Data appended successfully
#  048_tiny Data appended successfully
#  049_tiny Data appended successfully
#  050_tiny Data appended successfully
#  051_tiny Data appended successfully
#  052_tiny Data appended successfully
#  053_tiny Data appended successfully
#  054_tiny Data appended successfully
#  055_tiny Data appended successfully
#  056_tiny Data appended successfully
#  057_tiny Data appended successfully
#  058_tiny Data appended successfully
#  059_tiny Data appended successfully
#  060_tiny Data appended successfully
#  061_tiny Data appended successfully
#  062_tiny Data appended successfully
#  063_tiny Data appended successfully
#  064_tiny Data appended successfully
#  065_tiny Data appended successfully
#  066_tiny Data appended successfully
#  067_tiny Data appended successfully
#  068_tiny Data appended successfully
#  069_tiny Data appended successfully
#  070_tiny Data appended successfully
#  071_tiny Data appended successfully
#  072_tiny Data appended successfully
#  073_tiny Data appended successfully
#  074_tiny Data appended successfully
#  075_tiny Data appended successfully
#  076_tiny Data appended successfully
#  077_tiny Data appended successfully
#  078_tiny Data appended successfully
#  079_tiny Data appended successfully
#  080_tiny Data appended successfully
#  081_tiny Data appended successfully
#  082_tiny Data appended successfully
#  083_tiny Data appended successfully
#  084_tiny Data appended successfully
#  085_tiny Data appended successfully
#  086_tiny Data appended successfully
#  087_tiny Data appended successfully
#  088_tiny Data appended successfully
#  089_tiny Data appended successfully
#  090_tiny Data appended successfully
#  091_tiny Data appended successfully
#  092_tiny Data appended successfully
#  093_tiny Data appended successfully
#  094_tiny Data appended successfully
#  095_tiny Data appended successfully
#  096_tiny Data appended successfully
#  097_tiny Data appended successfully
#  098_tiny Data appended successfully
#  099_tiny Data appended successfully
#  100_tiny Data appended successfully
#  101_tiny Data appended successfully
#  102_tiny Data appended successfully
#  103_tiny Data appended successfully
#  104_tiny Data appended successfully
#  105_tiny Data appended successfully
#  106_tiny Data appended successfully
#  107_tiny Data appended successfully
#  108_tiny Data appended successfully
#  109_tiny Data appended successfully
#  110_tiny Data appended successfully
#  111_tiny Data appended successfully
#  112_tiny Data appended successfully
#  113_tiny Data appended successfully
#  114_tiny Data appended successfully
#  115_tiny Data appended successfully
#  116_tiny Data appended successfully
#  117_tiny Data appended successfully
#  118_tiny Data appended successfully
#  119_tiny Data appended successfully
#  120_tiny Data appended successfully
#  121_tiny Data appended successfully
#  122_tiny Data appended successfully
#  123_tiny Data appended successfully
#  124_tiny Data appended successfully
#  125_tiny Data appended successfully
#  126_tiny Data appended successfully
#  127_tiny Data appended successfully
#  128_tiny Data appended successfully
#  129_tiny Data appended successfully
#  130_tiny Data appended successfully
#  131_tiny Data appended successfully
#  132_tiny Data appended successfully
#  133_tiny Data appended successfully
#  134_tiny Data appended successfully
#  135_tiny Data appended successfully
#  136_tiny Data appended successfully
#  137_tiny Data appended successfully
#  138_tiny Data appended successfully
#  139_tiny Data appended successfully
#  140_tiny Data appended successfully
#  141_tiny Data appended successfully
#  142_tiny Data appended successfully
#  143_tiny Data appended successfully
#  144_tiny Data appended successfully
#  145_tiny Data appended successfully
#  146_tiny Data appended successfully
#  147_tiny Data appended successfully
#  148_tiny Data appended successfully
#  149_tiny Data appended successfully
#  150_tiny Data appended successfully
#  151_tiny Data appended successfully
#  152_tiny Data appended successfully
#  153_tiny Data appended successfully
#  154_tiny Data appended successfully
#  155_tiny Data appended successfully
#  156_tiny Data appended successfully
#  157_tiny Data appended successfully
#  158_tiny Data appended successfully
#  159_tiny Data appended successfully
#  160_tiny Data appended successfully
#  161_tiny Data appended successfully
#  162_tiny Data appended successfully
#  163_tiny Data appended successfully
#  164_tiny Data appended successfully
#  165_tiny Data appended successfully
#  166_tiny Data appended successfully
#  167_tiny Data appended successfully
#  168_tiny Data appended successfully
#  169_tiny Data appended successfully
#  170_tiny Data appended successfully
#  171_tiny Data appended successfully
#  172_tiny Data appended successfully
#  173_tiny Data appended successfully
#  174_tiny Data appended successfully
#  175_tiny Data appended successfully
#  176_tiny Data appended successfully
#  177_tiny Data appended successfully
#  178_tiny Data appended successfully
#  179_tiny Data appended successfully
#  180_tiny Data appended successfully
#  181_tiny Data appended successfully
#  182_tiny Data appended successfully
#  183_tiny Data appended successfully
#  184_tiny Data appended successfully
#  185_tiny Data appended successfully
#  186_tiny Data appended successfully
#  187_tiny Data appended successfully
#  188_tiny Data appended successfully
#  189_tiny Data appended successfully
#  190_tiny Data appended successfully
#  191_tiny Data appended successfully
#  192_tiny Data appended successfully
#  193_tiny Data appended successfully
#  194_tiny Data appended successfully
#  195_tiny Data appended successfully
#  196_tiny Data appended successfully
#  197_tiny Data appended successfully
#  198_tiny Data appended successfully
#  199_tiny Data appended successfully
#  200_tiny Data appended successfully
#  201_tiny Data appended successfully
#  202_tiny Data appended successfully
#  203_tiny Data appended successfully
#  204_tiny Data appended successfully
#  205_tiny Data appended successfully
#  206_tiny Data appended successfully
#  207_tiny Data appended successfully
#  208_tiny Data appended successfully
#  209_tiny Data appended successfully
#  210_tiny Data appended successfully
#  211_tiny Data appended successfully
#  212_tiny Data appended successfully
#  213_tiny Data appended successfully
#  214_tiny Data appended successfully
#  215_tiny Data appended successfully
#  216_tiny Data appended successfully
#  217_tiny Data appended successfully
#  218_tiny Data appended successfully
#  219_tiny Data appended successfully
#  220_tiny Data appended successfully
#  221_tiny Data appended successfully
#  222_tiny Data appended successfully
#  223_tiny Data appended successfully
#  224_tiny Data appended successfully
#  225_tiny Data appended successfully
#  226_tiny Data appended successfully
#  227_tiny Data appended successfully
#  228_tiny Data appended successfully
#  229_tiny Data appended successfully
#  230_tiny Data appended successfully
#  231_tiny Data appended successfully
#  232_tiny Data appended successfully
#  233_tiny Data appended successfully
#  234_tiny Data appended successfully
#  235_tiny Data appended successfully
#  236_tiny Data appended successfully
#  237_tiny Data appended successfully
#  238_tiny Data appended successfully
#  239_tiny Data appended successfully
#  240_tiny Data appended successfully
#  241_tiny Data appended successfully
#  242_tiny Data appended successfully
#  243_tiny Data appended successfully
#  244_tiny Data appended successfully
#  245_tiny Data appended successfully
#  246_tiny Data appended successfully
#  247_tiny Data appended successfully
#  248_tiny Data appended successfully
#  249_tiny Data appended successfully
#  250_tiny Data appended successfully
#  251_tiny Data appended successfully
#  252_tiny Data appended successfully
#  253_tiny Data appended successfully
#  254_tiny Data appended successfully
#  255_tiny Data appended successfully
#  256_tiny Data appended successfully
#  257_tiny Data appended successfully
#  258_tiny Data appended successfully
#  259_tiny Data appended successfully
#  260_tiny Data appended successfully
#  261_tiny Data appended successfully
#  262_tiny Data appended successfully
#  263_tiny Data appended successfully
#  264_tiny Data appended successfully
#  265_tiny Data appended successfully
#  266_tiny Data appended successfully
#  267_tiny Data appended successfully
#  268_tiny Data appended successfully
#  269_tiny Data appended successfully
#  270_tiny Data appended successfully
#  271_tiny Data appended successfully
#  272_tiny Data appended successfully
#  273_tiny Data appended successfully
#  274_tiny Data appended successfully
#  275_tiny Data appended successfully
#  276_tiny Data appended successfully
#  277_tiny Data appended successfully
#  278_tiny Data appended successfully
#  279_tiny Data appended successfully
#  280_tiny Data appended successfully
#  281_tiny Data appended successfully
#  282_tiny Data appended successfully
#  283_tiny Data appended successfully
#  284_tiny Data appended successfully
#  285_tiny Data appended successfully
#  286_tiny Data appended successfully
#  287_tiny Data appended successfully
#  288_tiny Data appended successfully
#  289_tiny Data appended successfully
#  290_tiny Data appended successfully
#  291_tiny Data appended successfully
#  292_tiny Data appended successfully
#  293_tiny Data appended successfully
#  294_tiny Data appended successfully
#  295_tiny Data appended successfully
#  296_tiny Data appended successfully
#  297_tiny Data appended successfully
#  298_tiny Data appended successfully
#  299_tiny Data appended successfully
#  300_tiny Data appended successfully
#  301_tiny Data appended successfully
#  302_tiny Data appended successfully
#  303_tiny Data appended successfully
#  304_tiny Data appended successfully
#  305_tiny Data appended successfully
#  306_tiny Data appended successfully
#  307_tiny Data appended successfully
#  308_tiny Data appended successfully
#  309_tiny Data appended successfully
#  310_tiny Data appended successfully
#  311_tiny Data appended successfully
#  312_tiny Data appended successfully
#  313_tiny Data appended successfully
#  314_tiny Data appended successfully
#  315_tiny Data appended successfully
#  316_tiny Data appended successfully
#  317_tiny Data appended successfully
#  318_tiny Data appended successfully
#  319_tiny Data appended successfully
#  320_tiny Data appended successfully
#  321_tiny Data appended successfully
#  322_tiny Data appended successfully
#  323_tiny Data appended successfully
#  324_tiny Data appended successfully
#  325_tiny Data appended successfully
#  326_tiny Data appended successfully
#  327_tiny Data appended successfully
#  328_tiny Data appended successfully
#  329_tiny Data appended successfully
#  330_tiny Data appended successfully
#  331_tiny Data appended successfully
#  332_tiny Data appended successfully
#  333_tiny Data appended successfully
#  334_tiny Data appended successfully
#  335_tiny Data appended successfully
#  336_tiny Data appended successfully
#  337_tiny Data appended successfully
#  338_tiny Data appended successfully
#  339_tiny Data appended successfully
#  340_tiny Data appended successfully
#  341_tiny Data appended successfully
#  342_tiny Data appended successfully
#  343_tiny Data appended successfully
#  344_tiny Data appended successfully
#  345_tiny Data appended successfully
#  346_tiny Data appended successfully
#  347_tiny Data appended successfully
#  348_tiny Data appended successfully
#  349_tiny Data appended successfully
#  350_tiny Data appended successfully
#  351_tiny Data appended successfully
#  352_tiny Data appended successfully
#  353_tiny Data appended successfully
#  354_tiny Data appended successfully
#  355_tiny Data appended successfully
#  356_tiny Data appended successfully
#  357_tiny Data appended successfully
#  358_tiny Data appended successfully
#  359_tiny Data appended successfully
#  360_tiny Data appended successfully
#  361_tiny Data appended successfully
#  362_tiny Data appended successfully
#  363_tiny Data appended successfully
#  364_tiny Data appended successfully
#  365_tiny Data appended successfully
#  366_tiny Data appended successfully
#  367_tiny Data appended successfully
#  368_tiny Data appended successfully
#  369_tiny Data appended successfully
#  370_tiny Data appended successfully
#  371_tiny Data appended successfully
#  372_tiny Data appended successfully
#  373_tiny Data appended successfully
#  374_tiny Data appended successfully
#  375_tiny Data appended successfully
#  376_tiny Data appended successfully
#  377_tiny Data appended successfully
#  378_tiny Data appended successfully
#  379_tiny Data appended successfully
#  380_tiny Data appended successfully
#  381_tiny Data appended successfully
#  382_tiny Data appended successfully
#  383_tiny Data appended successfully
#  384_tiny Data appended successfully
#  385_tiny Data appended successfully
#  386_tiny Data appended successfully
#  387_tiny Data appended successfully
#  388_tiny Data appended successfully
#  389_tiny Data appended successfully
#  390_tiny Data appended successfully
#  391_tiny Data appended successfully
#  392_tiny Data appended successfully
#  393_tiny Data appended successfully
#  394_tiny Data appended successfully
#  395_tiny Data appended successfully
#  396_tiny Data appended successfully
#  397_tiny Data appended successfully
#  398_tiny Data appended successfully
#  399_tiny Data appended successfully
#  transcribing /media/arpagon/archive-data/Insync/arpagon@gmail.com/AI/podcast/audio/400.mp3 at 1666920918.4559462
